# 687  b  17.92   0.205  u  g  aa   v  0.040  f   f   0  f   g  00280  750  -
# 688  b  35.00   3.375  u  g   c   h  8.290  f   f   0  t   g  00000    0  -

# %%
df.shape
# Out:
# (689, 16)

# %%
names = []
for i in range(df.shape[1]):
    if i<df.shape[1]-1:
        names.append("var"+str(i))
    else:
        names.append("Alvo")

df.columns = names

# %%
df['var0'].replace("?", inplace=True , method='ffill')

# %%
 df.tail(20)
# Out:
#     var0   var1    var2 var3 var4 var5 var6   var7 var8 var9  var10 var11  \
# 669    b  47.17   5.835    u    g    w    v  5.500    f    f      0     f
# 670    b  25.83  12.835    u    g   cc    v  0.500    f    f      0     f
# 671    a  50.25   0.835    u    g   aa    v  0.500    f    f      0     t
# 672    a  29.50   2.000    y    p    e    h  2.000    f    f      0     f
# 673    a  37.33   2.500    u    g    i    h  0.210    f    f      0     f
# 674    a  41.58   1.040    u    g   aa    v  0.665    f    f      0     f
# 675    a  30.58  10.665    u    g    q    h  0.085    f    t     12     t
# 676    b  19.42   7.250    u    g    m    v  0.040    f    t      1     f
# 677    a  17.92  10.210    u    g   ff   ff  0.000    f    f      0     f
# 678    a  20.08   1.250    u    g    c    v  0.000    f    f      0     f
# 679    b  19.50   0.290    u    g    k    v  0.290    f    f      0     f
# 680    b  27.83   1.000    y    p    d    h  3.000    f    f      0     f
# 681    b  17.08   3.290    u    g    i    v  0.335    f    f      0     t
# 682    b  36.42   0.750    y    p    d    v  0.585    f    f      0     f
# 683    b  40.58   3.290    u    g    m    v  3.500    f    f      0     t
# 684    b  21.08  10.085    y    p    e    h  1.250    f    f      0     f
# 685    a  22.67   0.750    u    g    c    v  2.000    f    t      2     t
# 686    a  25.25  13.500    y    p   ff   ff  2.000    f    t      1     t
# 687    b  17.92   0.205    u    g   aa    v  0.040    f    f      0     f
# 688    b  35.00   3.375    u    g    c    h  8.290    f    f      0     t
#
#     var12  var13  var14 Alvo
# 669     g  00465    150    -
# 670     g  00000      2    -
# 671     g  00240    117    -
# 672     g  00256     17    -
# 673     g  00260    246    -
# 674     g  00240    237    -
# 675     g  00129      3    -
# 676     g  00100      1    -
# 677     g  00000     50    -
# 678     g  00000      0    -
# 679     g  00280    364    -
# 680     g  00176    537    -
# 681     g  00140      2    -
# 682     g  00240      3    -
# 683     s  00400      0    -
# 684     g  00260      0    -
# 685     g  00200    394    -
# 686     g  00200      1    -
# 687     g  00280    750    -
# 688     g  00000      0    -

# %%
print(df.isnull().sum())
print(df.isna().sum())
# Out:
# var0     0
# var1     0
# var2     0
# var3     0
# var4     0
# var5     0
# var6     0
# var7     0
# var8     0
# var9     0
# var10    0
# var11    0
# var12    0
# var13    0
# var14    0
# Alvo     0
# dtype: int64
# var0     0
# var1     0
# var2     0
# var3     0
# var4     0
# var5     0
# var6     0
# var7     0
# var8     0
# var9     0
# var10    0
# var11    0
# var12    0
# var13    0
# var14    0
# Alvo     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var0    689 non-null    object
#  1   var1    689 non-null    object
#  2   var2    689 non-null    float64
#  3   var3    689 non-null    object
#  4   var4    689 non-null    object
#  5   var5    689 non-null    object
#  6   var6    689 non-null    object
#  7   var7    689 non-null    float64
#  8   var8    689 non-null    object
#  9   var9    689 non-null    object
#  10  var10   689 non-null    int64
#  11  var11   689 non-null    object
#  12  var12   689 non-null    object
#  13  var13   689 non-null    object
#  14  var14   689 non-null    int64
#  15  Alvo    689 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.2+ KB

# %%
# Out:
# Index(['var0', 'var1', 'var2', 'var3', 'var4', 'var5', 'var6', 'var7', 'var8',
#        'var9', 'var10', 'var11', 'var12', 'var13', 'var14', 'Alvo'],
#       dtype='object')
